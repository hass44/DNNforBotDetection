# %%
import pandas as pd
import numpy as np
import math

from keras.layers import Embedding, Dense, LSTM, Dense, Input, concatenate
from keras.models import Model
from keras.utils import plot_model
from sklearn.metrics import precision_score, roc_auc_score, recall_score, f1_score
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import pandas as pd

bot_accounts = pd.concat([pd.read_csv('D:/DNNforBotDetection/DNNforBotDetection/input/cresci-2017.csv/social_spambots_1/users.csv'),
                         pd.read_csv('D:/DNNforBotDetection/DNNforBotDetection/input/cresci-2017.csv/social_spambots_2/users.csv'),
                         pd.read_csv('D:/DNNforBotDetection/DNNforBotDetection/input/cresci-2017.csv/social_spambots_3/users.csv')]).reset_index(drop=True)
clean_accounts = pd.read_csv('D:/DNNforBotDetection/DNNforBotDetection/input/cresci-2017.csv/genuine_accounts/users.csv')

requiredColumns = ['screen_name', 'created_at', 'updated', 'location', 'statuses_count', 'friends_count',
                   'followers_count', 'favourites_count', 'default_profile_image', 'profile_use_background_image',
                   'protected', 'default_profile']
bot_accounts = bot_accounts[requiredColumns]
clean_accounts = clean_accounts[requiredColumns]

def clean_df(df):
    df['created_at'] = pd.to_datetime(df['created_at']).dt.tz_localize(None).dt.tz_localize('UTC')  # Convert to UTC timezone
    df['updated'] = pd.to_datetime(df['updated']).dt.tz_localize(None).dt.tz_localize('UTC')  # Convert to UTC timezone
    df['age'] = (df['updated'] - df['created_at']).dt.days  # Use dt.days to get the number of days
    df['has_location'] = df['location'].notnull().astype(int)  # Convert boolean to integer
    df['has_avatar'] = df['default_profile_image'].notnull().astype(int)
    df['has_background'] = df['profile_use_background_image'].notnull().astype(int)
    df['is_protected'] = df['protected'].notnull().astype(int)
    df['profile_modified'] = df['default_profile'].notnull().astype(int)
    df = df.rename(columns={"screen_name": "username", "statuses_count": "total_tweets", "friends_count": "total_following",
                            "followers_count": "total_followers", "favourites_count": "total_likes"})
    return df[['username', 'age', 'has_location', 'total_tweets', 'total_following', 'total_followers',
               'total_likes', 'has_avatar', 'has_background', 'is_protected', 'profile_modified']]

bot_accounts = clean_df(bot_accounts)
clean_accounts = clean_df(clean_accounts)

# %%
bot_accounts['BotOrNot'] = 1
clean_accounts['BotOrNot'] = 0

combined_df = pd.concat([bot_accounts, clean_accounts])

new_df = combined_df.sample(frac=1).reset_index(drop=True)

# %%
bot_accounts
# Out:
#              username   age  has_location  total_tweets  total_following  \
# 0           davideb66  2555             0          1299               40
# 1        ElisaDospina  2521             1         18665             3442
# 2          Vladimir65  2497             1         22987              755
# 3      RafielaMorales  2435             1          7975              350
# 4         FabrizioC_c  2413             1         20218              405
# ...               ...   ...           ...           ...              ...
# 4907   AldridgeBizOpp   728             1           106               23
# 4908    DLBusinessOpp   728             1           173               20
# 4909  LFCareerOptions   709             1           137              124
# 4910      RickChou_TD   709             1           170              353
# 4911    CKSmallBizOpp   704             1            65              998
#
#       total_followers  total_likes  has_avatar  has_background  is_protected  \
# 0                  22            1           1               1             0
# 1               12561        16358           0               1             0
# 2                 600           14           0               1             0
# 3                 398           11           0               1             0
# 4                 413          162           0               1             0
# ...               ...          ...         ...             ...           ...
# 4907                4            0           0               1             0
# 4908                2            0           0               1             0
# 4909               29            0           0               1             0
# 4910              115           38           0               1             0
# 4911              135            0           0               1             0
#
#       profile_modified  BotOrNot
# 0                    1         1
# 1                    0         1
# 2                    0         1
# 3                    0         1
# 4                    0         1
# ...                ...       ...
# 4907                 0         1
# 4908                 0         1
# 4909                 0         1
# 4910                 0         1
# 4911                 0         1
#
# [4912 rows x 12 columns]

# %%
training_df = new_df.drop('username', axis=1)[:int(combined_df.shape[0] * 0.8)]
test_df = new_df.drop('username', axis=1)[int(combined_df.shape[0] * 0.8):]

columns_to_standardize = ['age', 'total_tweets', 'total_following', 'total_followers', 'total_likes']

training_df_mean = training_df[columns_to_standardize].mean()
training_df_std = training_df[columns_to_standardize].std()

training_df[columns_to_standardize] = (training_df[columns_to_standardize] - training_df_mean)/training_df_std
test_df[columns_to_standardize] = (test_df[columns_to_standardize] - training_df_mean)/training_df_std

# training_df_mean = training_df.mean()
# training_df_std = training_df.std()

# training_df = (training_df - training_df_mean)/training_df_std
# test_df = (test_df - training_df_mean)/training_df_std

# max_vals = training_df.max()

# training_df = training_df/max_vals
# test_df = test_df/max_vals

# %%
test_df
# Out:
#            age  has_location  total_tweets  total_following  total_followers  \
# 6708 -0.768271             0     -0.367037        -0.277217        -0.072157
# 6709  2.194420             1      0.052771         0.271688        -0.041939
# 6710 -0.764959             0     -0.367410        -0.277217        -0.071720
# 6711 -0.750054             0     -0.365828        -0.276725        -0.072157
# 6712 -0.755022             0     -0.366805        -0.277709        -0.071793
# ...        ...           ...           ...              ...              ...
# 8381 -0.758335             0     -0.366572        -0.280168        -0.071866
# 8382 -0.753366             0     -0.366572        -0.277217        -0.072084
# 8383 -0.523174             1     -0.356477        -0.258527        -0.070337
# 8384 -0.771583             0     -0.367037        -0.280168        -0.071938
# 8385 -0.759991             0     -0.367549        -0.277709        -0.071720
#
#       total_likes  has_avatar  has_background  is_protected  profile_modified  \
# 6708    -0.251898           0               1             0                 0
# 6709    -0.224139           0               1             0                 0
# 6710    -0.251898           0               1             0                 0
# 6711    -0.251898           0               1             0                 0
# 6712    -0.251898           0               1             0                 0
# ...           ...         ...             ...           ...               ...
# 8381    -0.251898           0               1             0                 0
# 8382    -0.251898           0               1             0                 0
# 8383    -0.203351           0               1             0                 1
# 8384    -0.251898           0               1             0                 0
# 8385    -0.251898           0               1             0                 0
#
#       BotOrNot
# 6708         1
# 6709         0
# 6710         1
# 6711         1
# 6712         1
# ...        ...
# 8381         1
# 8382         1
# 8383         0
# 8384         1
# 8385         1
#
# [1678 rows x 11 columns]

# %%
X_train = training_df.drop(['BotOrNot', 'is_protected'], axis=1).values
y_train = training_df['BotOrNot'].values.reshape(-1,1)

X_test = test_df.drop(['BotOrNot', 'is_protected'], axis=1).values
y_test = test_df['BotOrNot'].values.reshape(-1,1)

# %%
X_test[0]
# Out:
# array([-0.76827094,  0.        , -0.36703735, -0.27721707, -0.07215691,
#        -0.25189841,  0.        ,  1.        ,  0.        ])

# %%
from imblearn.over_sampling import SMOTE

s = SMOTE()
smote_X, smote_y = s.fit_resample(X_train, y_train.reshape(-1))

# e = EditedNearestNeighbours()
# r_X, r_y = e.fit_resample(smote_X, smote_y)

# %%
inp = Input(shape=[9])

another = Dense(500, activation='relu')(inp)
another = Dense(200, activation='relu')(another)
another = Dense(1, activation='sigmoid')(another)

mod = Model(inp, another)
mod.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
training = mod.fit(x=smote_X, y=smote_y, batch_size=64, epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 123/123 [==============================] - 1s 2ms/step - loss: 0.2384 - accuracy: 0.9138 - val_loss: 0.1396 - val_accuracy: 0.9559
# Epoch 2/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.1339 - accuracy: 0.9596 - val_loss: 0.1044 - val_accuracy: 0.9678
# Epoch 3/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.1107 - accuracy: 0.9684 - val_loss: 0.0930 - val_accuracy: 0.9738
# Epoch 4/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0949 - accuracy: 0.9711 - val_loss: 0.0893 - val_accuracy: 0.9726
# Epoch 5/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0857 - accuracy: 0.9735 - val_loss: 0.0850 - val_accuracy: 0.9756
# Epoch 6/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0811 - accuracy: 0.9758 - val_loss: 0.0725 - val_accuracy: 0.9774
# Epoch 7/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0772 - accuracy: 0.9768 - val_loss: 0.0952 - val_accuracy: 0.9738
# Epoch 8/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.9777 - val_loss: 0.0759 - val_accuracy: 0.9726
# Epoch 9/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 0.9772 - val_loss: 0.0711 - val_accuracy: 0.9762
# Epoch 10/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9785 - val_loss: 0.0644 - val_accuracy: 0.9774
# Epoch 11/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0630 - accuracy: 0.9794 - val_loss: 0.1029 - val_accuracy: 0.9678
# Epoch 12/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9777 - val_loss: 0.0653 - val_accuracy: 0.9791
# Epoch 13/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0596 - accuracy: 0.9813 - val_loss: 0.0687 - val_accuracy: 0.9803
# Epoch 14/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0589 - accuracy: 0.9817 - val_loss: 0.0687 - val_accuracy: 0.9768
# Epoch 15/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0566 - accuracy: 0.9823 - val_loss: 0.0714 - val_accuracy: 0.9803
# Epoch 16/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0541 - accuracy: 0.9827 - val_loss: 0.0661 - val_accuracy: 0.9768
# Epoch 17/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 0.9828 - val_loss: 0.0633 - val_accuracy: 0.9779
# Epoch 18/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 0.9829 - val_loss: 0.0684 - val_accuracy: 0.9756
# Epoch 19/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0519 - accuracy: 0.9818 - val_loss: 0.0772 - val_accuracy: 0.9732
# Epoch 20/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0561 - accuracy: 0.9813 - val_loss: 0.0639 - val_accuracy: 0.9791
# Epoch 21/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 0.9850 - val_loss: 0.0713 - val_accuracy: 0.9744
# Epoch 22/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0505 - accuracy: 0.9836 - val_loss: 0.0674 - val_accuracy: 0.9768
# Epoch 23/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0529 - accuracy: 0.9824 - val_loss: 0.0633 - val_accuracy: 0.9774
# Epoch 24/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0506 - accuracy: 0.9836 - val_loss: 0.0720 - val_accuracy: 0.9768
# Epoch 25/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0484 - accuracy: 0.9838 - val_loss: 0.0751 - val_accuracy: 0.9726
# Epoch 26/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0493 - accuracy: 0.9833 - val_loss: 0.0651 - val_accuracy: 0.9815
# Epoch 27/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0469 - accuracy: 0.9854 - val_loss: 0.0665 - val_accuracy: 0.9762
# Epoch 28/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9859 - val_loss: 0.0664 - val_accuracy: 0.9768
# Epoch 29/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0456 - accuracy: 0.9843 - val_loss: 0.0667 - val_accuracy: 0.9774
# Epoch 30/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0456 - accuracy: 0.9841 - val_loss: 0.0883 - val_accuracy: 0.9762
# Epoch 31/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0465 - accuracy: 0.9842 - val_loss: 0.0656 - val_accuracy: 0.9785
# Epoch 32/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0475 - accuracy: 0.9837 - val_loss: 0.0869 - val_accuracy: 0.9732
# Epoch 33/100
# 123/123 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9855 - val_loss: 0.0708 - val_accuracy: 0.9791
# Epoch 34/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0439 - accuracy: 0.9865 - val_loss: 0.0667 - val_accuracy: 0.9797
# Epoch 35/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0431 - accuracy: 0.9862 - val_loss: 0.0738 - val_accuracy: 0.9791
# Epoch 36/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0498 - accuracy: 0.9843 - val_loss: 0.0669 - val_accuracy: 0.9774
# Epoch 37/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0452 - accuracy: 0.9852 - val_loss: 0.0717 - val_accuracy: 0.9797
# Epoch 38/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0437 - accuracy: 0.9868 - val_loss: 0.0663 - val_accuracy: 0.9768
# Epoch 39/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0446 - accuracy: 0.9866 - val_loss: 0.0652 - val_accuracy: 0.9809
# Epoch 40/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0452 - accuracy: 0.9855 - val_loss: 0.0676 - val_accuracy: 0.9797
# Epoch 41/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0451 - accuracy: 0.9855 - val_loss: 0.0642 - val_accuracy: 0.9791
# Epoch 42/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0402 - accuracy: 0.9875 - val_loss: 0.0662 - val_accuracy: 0.9774
# Epoch 43/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0410 - accuracy: 0.9871 - val_loss: 0.0645 - val_accuracy: 0.9797
# Epoch 44/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0398 - accuracy: 0.9869 - val_loss: 0.0657 - val_accuracy: 0.9774
# Epoch 45/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9882 - val_loss: 0.0628 - val_accuracy: 0.9809
# Epoch 46/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0397 - accuracy: 0.9875 - val_loss: 0.0689 - val_accuracy: 0.9809
# Epoch 47/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0388 - accuracy: 0.9869 - val_loss: 0.0648 - val_accuracy: 0.9785
# Epoch 48/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0419 - accuracy: 0.9871 - val_loss: 0.0793 - val_accuracy: 0.9768
# Epoch 49/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0423 - accuracy: 0.9870 - val_loss: 0.0713 - val_accuracy: 0.9797
# Epoch 50/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9860 - val_loss: 0.0816 - val_accuracy: 0.9744
# Epoch 51/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0415 - accuracy: 0.9865 - val_loss: 0.0645 - val_accuracy: 0.9803
# Epoch 52/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0403 - accuracy: 0.9878 - val_loss: 0.0671 - val_accuracy: 0.9750
# Epoch 53/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0384 - accuracy: 0.9866 - val_loss: 0.0670 - val_accuracy: 0.9791
# Epoch 54/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0403 - accuracy: 0.9869 - val_loss: 0.0734 - val_accuracy: 0.9738
# Epoch 55/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9866 - val_loss: 0.0732 - val_accuracy: 0.9785
# Epoch 56/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0386 - accuracy: 0.9888 - val_loss: 0.0736 - val_accuracy: 0.9774
# Epoch 57/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0359 - accuracy: 0.9887 - val_loss: 0.0715 - val_accuracy: 0.9779
# Epoch 58/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0375 - accuracy: 0.9883 - val_loss: 0.0690 - val_accuracy: 0.9774
# Epoch 59/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0353 - accuracy: 0.9885 - val_loss: 0.0634 - val_accuracy: 0.9821
# Epoch 60/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0346 - accuracy: 0.9883 - val_loss: 0.0746 - val_accuracy: 0.9785
# Epoch 61/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0363 - accuracy: 0.9889 - val_loss: 0.0693 - val_accuracy: 0.9791
# Epoch 62/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0370 - accuracy: 0.9876 - val_loss: 0.0733 - val_accuracy: 0.9779
# Epoch 63/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0341 - accuracy: 0.9889 - val_loss: 0.0715 - val_accuracy: 0.9768
# Epoch 64/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0364 - accuracy: 0.9879 - val_loss: 0.0693 - val_accuracy: 0.9791
# Epoch 65/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0359 - accuracy: 0.9884 - val_loss: 0.0764 - val_accuracy: 0.9779
# Epoch 66/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 0.9893 - val_loss: 0.0688 - val_accuracy: 0.9768
# Epoch 67/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0348 - accuracy: 0.9888 - val_loss: 0.0711 - val_accuracy: 0.9803
# Epoch 68/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0475 - accuracy: 0.9865 - val_loss: 0.0680 - val_accuracy: 0.9762
# Epoch 69/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0371 - accuracy: 0.9882 - val_loss: 0.0671 - val_accuracy: 0.9791
# Epoch 70/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 0.9896 - val_loss: 0.0767 - val_accuracy: 0.9779
# Epoch 71/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0344 - accuracy: 0.9880 - val_loss: 0.0697 - val_accuracy: 0.9779
# Epoch 72/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0333 - accuracy: 0.9891 - val_loss: 0.0697 - val_accuracy: 0.9779
# Epoch 73/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0339 - accuracy: 0.9883 - val_loss: 0.0733 - val_accuracy: 0.9762
# Epoch 74/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 0.9878 - val_loss: 0.0692 - val_accuracy: 0.9779
# Epoch 75/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0316 - accuracy: 0.9892 - val_loss: 0.0898 - val_accuracy: 0.9756
# Epoch 76/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0391 - accuracy: 0.9873 - val_loss: 0.0691 - val_accuracy: 0.9821
# Epoch 77/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0323 - accuracy: 0.9887 - val_loss: 0.0752 - val_accuracy: 0.9785
# Epoch 78/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 0.0715 - val_accuracy: 0.9768
# Epoch 79/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0315 - accuracy: 0.9898 - val_loss: 0.0759 - val_accuracy: 0.9768
# Epoch 80/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0345 - accuracy: 0.9882 - val_loss: 0.0710 - val_accuracy: 0.9785
# Epoch 81/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0339 - accuracy: 0.9884 - val_loss: 0.0679 - val_accuracy: 0.9809
# Epoch 82/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0331 - accuracy: 0.9884 - val_loss: 0.0681 - val_accuracy: 0.9785
# Epoch 83/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 0.9905 - val_loss: 0.0760 - val_accuracy: 0.9791
# Epoch 84/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 0.9891 - val_loss: 0.0799 - val_accuracy: 0.9774
# Epoch 85/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0308 - accuracy: 0.9902 - val_loss: 0.0706 - val_accuracy: 0.9785
# Epoch 86/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0312 - accuracy: 0.9897 - val_loss: 0.0711 - val_accuracy: 0.9774
# Epoch 87/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0331 - accuracy: 0.9887 - val_loss: 0.0708 - val_accuracy: 0.9791
# Epoch 88/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9899 - val_loss: 0.0833 - val_accuracy: 0.9744
# Epoch 89/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0330 - accuracy: 0.9893 - val_loss: 0.0703 - val_accuracy: 0.9803
# Epoch 90/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.9894 - val_loss: 0.0697 - val_accuracy: 0.9815
# Epoch 91/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0308 - accuracy: 0.9891 - val_loss: 0.0677 - val_accuracy: 0.9791
# Epoch 92/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0298 - accuracy: 0.9899 - val_loss: 0.0769 - val_accuracy: 0.9791
# Epoch 93/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 0.9897 - val_loss: 0.0746 - val_accuracy: 0.9785
# Epoch 94/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0311 - accuracy: 0.9903 - val_loss: 0.0692 - val_accuracy: 0.9803
# Epoch 95/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0376 - accuracy: 0.9892 - val_loss: 0.0779 - val_accuracy: 0.9774
# Epoch 96/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 0.9896 - val_loss: 0.0750 - val_accuracy: 0.9815
# Epoch 97/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0352 - accuracy: 0.9874 - val_loss: 0.0713 - val_accuracy: 0.9803
# Epoch 98/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 0.9894 - val_loss: 0.0681 - val_accuracy: 0.9756
# Epoch 99/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0403 - accuracy: 0.9887 - val_loss: 0.0823 - val_accuracy: 0.9744
# Epoch 100/100
# 123/123 [==============================] - 0s 1ms/step - loss: 0.0324 - accuracy: 0.9891 - val_loss: 0.0681 - val_accuracy: 0.9791

# %%
X_test[100]
# Out:
# array([ 0.62613125,  1.        , -0.14522387, -0.17687954, -0.06392884,
#        -0.17197617,  0.        ,  1.        ,  0.        ])

# %%
# Evaluating the model
y_pred_prob = mod.predict(X_test)
y_pred = (y_pred_prob >= 0.5).astype(int)
y_scores = y_pred_prob.ravel()

recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_scores)

print("Recall Score:", recall)
print("F1 Score:", f1)
print("ROC/AUC Score:", roc_auc)
# Out:
# 53/53 [==============================] - 0s 607us/step
# Recall Score: 0.9756345177664975
# F1 Score: 0.9821154828819622
# ROC/AUC Score: 0.9962218266786795

# %%
mod.save('D:/DNNforBotDetection/DNNforBotDetection/models/model.h5')

# %%
def clean(df):
    
    df = df.drop('username', axis=1)
    
    df[columns_to_standardize] = (df[columns_to_standardize] - training_df_mean)/training_df_std
    df = df.drop('is_protected', axis=1).values
    return df

# %%
first = bot_accounts.head(1)
first
first[columns_to_standardize]
# Out:
#     age  total_tweets  total_following  total_followers  total_likes
# 0  2555          1299               40               22            1

# %%
clean(first)
# Out:
# array([[ 2.23085301,  0.        , -0.30921139, -0.27869262, -0.07084624,
#         -0.25176929,  1.        ,  1.        ,  1.        ,  1.        ]])
